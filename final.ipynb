# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import os
import matplotlib.pyplot as plt

from app.settings import DATA_DIR
from app.core import load_image, do_thin

# %%
# %matplotlib inline

# %%
IMAGE_PATH = os.path.join(DATA_DIR, 'picture_5.jpg')

# %%
image = load_image(IMAGE_PATH)

# %%
thin_image = do_thin(image, ratio=0.9)
# Out:
# Processing 1 images
# image                    shape: (1002, 564, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.imshow(thin_image)
